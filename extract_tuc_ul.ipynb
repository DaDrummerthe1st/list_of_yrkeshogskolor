# %%
import re

import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url_tuc = 'https://www.tucsweden.se/om-tuc/kontakta-oss/'
get_tuc = requests.get(url_tuc)

# print(get_tuc.text)

# tuc_file = "tuc/Kontakta oss på TUC Yrkeshögskola.html"

# email_list = []

# with open(get_tuc) as f:
#     soup = BeautifulSoup(f, 'html.parser')
soup = BeautifulSoup(get_tuc.content, 'html.parser')

regex_email = r'mailto:[\w.+-]+@[\w-]+\.[\w.-]+'

print(soup.body)

a = soup.body.find(regex_email)
print(a)

# # print(soup)
# # print(type(soup))
# match = re.findall(regex, soup)
# email_list.append(f)
# emaildataframe = pd.DataFrame(email_list)

# display(emaildataframe)


# utbildningsledare = soup.find(data-avdelning="utbildningsledare")
# print(utbildningsledare)

# data-avdelning="utbildningsledare"

# data = []
# for index, h in enumerate(soup.find_all('mailto')):
#     print(h)
# Out:
# <body class="page-template page-template-pagetemplate-kontakt page-template-pagetemplate-kontakt-php page page-id-580 page-child parent-pageid-48" data-rsssl="1">
# <header id="header">
# <nav>
# <ul>
# <li class="logo">
# <a href="https://www.tucsweden.se" title="Till startsidan - TUC Sweden">
# ...
